# %%
# !pip install gymnasium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium) (0.0.4)

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[toy-text] in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium[toy-text]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium[toy-text]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium[toy-text]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in C:\Users\Dexter\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gymnasium[toy-text]) (2.6.1)

# %%
import gymnasium as gym
import numpy as np
import random

# %% [markdown]
# #### Sample Environments

# %%
env=gym.make("CliffWalking-v1")

# %%
print(env.observation_space.n) #states
print(env.action_space.n) #actions

starting_point,_=env.reset() #36=13*12+0
print(starting_point) #starting point
# Out:
# 48
# 4
# 36

# %% [markdown]
# ## SARSA

# %%
# define Parameters
gamma=0.99
alpha=0.5
epsilon=0.1
episodes=500
#Q-Table
Q=np.zeros((48,4))

# %%
#Policy epsilon -Greeedy : state -> action state base action
def epsilon_greedy(state):
    if random.random()<epsilon:
        return env.action_space.sample() #explore the state
    else:
        return np.argmax(Q[state])

# %% [markdown]
# ### Training Agent

# %%
for episode in range(episodes):
    # render=(episode%50==0)
    # if render:     
    #     env=gym.make("CliffWalking-v1",render_mode="human")
    #     print(f"episode for rendering ={episode}")
    # else:
    env=gym.make("CliffWalking-v1")
    done=False
    state,_=env.reset()
    action=epsilon_greedy(state)

    total_reward=0
    epsiode_len=0

    while not done:
        next_state,reward,terminated,truncated,_=env.step(action)
        done=terminated or truncated
        next_action=epsilon_greedy(next_state)

        # SARSA UPDATION  FORMULA
        Q[state,action] += alpha * (reward + gamma * (Q[next_state, next_action] - Q[state, action]))

        state=next_state
        action=next_action

        total_reward+=reward
        epsiode_len+=1
    print(f"episode={episode+1}/{episodes} and total rewards={total_reward} and episode length={epsiode_len}")
    env.close()
# Out:
# episode=1/500 and total rewards=-715 and episode length=220
# episode=2/500 and total rewards=-1677 and episode length=489
# episode=3/500 and total rewards=-95 and episode length=95
# episode=4/500 and total rewards=-85 and episode length=85
# episode=5/500 and total rewards=-41 and episode length=41
# episode=6/500 and total rewards=-70 and episode length=70
# episode=7/500 and total rewards=-58 and episode length=58
# episode=8/500 and total rewards=-55 and episode length=55
# episode=9/500 and total rewards=-550 and episode length=154
# episode=10/500 and total rewards=-194 and episode length=95
# episode=11/500 and total rewards=-27 and episode length=27
# episode=12/500 and total rewards=-198 and episode length=99
# episode=13/500 and total rewards=-54 and episode length=54
# episode=14/500 and total rewards=-37 and episode length=37
# episode=15/500 and total rewards=-25 and episode length=25
# episode=16/500 and total rewards=-35 and episode length=35
# episode=17/500 and total rewards=-29 and episode length=29
# episode=18/500 and total rewards=-65 and episode length=65
# episode=19/500 and total rewards=-32 and episode length=32
# episode=20/500 and total rewards=-28 and episode length=28
# episode=21/500 and total rewards=-45 and episode length=45
# episode=22/500 and total rewards=-136 and episode length=37
# episode=23/500 and total rewards=-35 and episode length=35
# episode=24/500 and total rewards=-23 and episode length=23
# episode=25/500 and total rewards=-31 and episode length=31
# episode=26/500 and total rewards=-25 and episode length=25
# episode=27/500 and total rewards=-165 and episode length=66
# episode=28/500 and total rewards=-154 and episode length=55
# episode=29/500 and total rewards=-27 and episode length=27
# episode=30/500 and total rewards=-41 and episode length=41
# episode=31/500 and total rewards=-27 and episode length=27
# episode=32/500 and total rewards=-152 and episode length=53
# episode=33/500 and total rewards=-38 and episode length=38
# episode=34/500 and total rewards=-25 and episode length=25
# episode=35/500 and total rewards=-21 and episode length=21
# episode=36/500 and total rewards=-49 and episode length=49
# episode=37/500 and total rewards=-36 and episode length=36
# episode=38/500 and total rewards=-28 and episode length=28
# episode=39/500 and total rewards=-22 and episode length=22
# episode=40/500 and total rewards=-27 and episode length=27
# episode=41/500 and total rewards=-19 and episode length=19
# episode=42/500 and total rewards=-21 and episode length=21
# episode=43/500 and total rewards=-27 and episode length=27
# episode=44/500 and total rewards=-27 and episode length=27
# episode=45/500 and total rewards=-19 and episode length=19
# episode=46/500 and total rewards=-33 and episode length=33
# episode=47/500 and total rewards=-25 and episode length=25
# episode=48/500 and total rewards=-47 and episode length=47
# episode=49/500 and total rewards=-20 and episode length=20
# episode=50/500 and total rewards=-26 and episode length=26
# episode=51/500 and total rewards=-20 and episode length=20
# episode=52/500 and total rewards=-20 and episode length=20
# episode=53/500 and total rewards=-17 and episode length=17
# episode=54/500 and total rewards=-23 and episode length=23
# episode=55/500 and total rewards=-21 and episode length=21
# episode=56/500 and total rewards=-19 and episode length=19
# episode=57/500 and total rewards=-25 and episode length=25
# episode=58/500 and total rewards=-21 and episode length=21
# episode=59/500 and total rewards=-33 and episode length=33
# episode=60/500 and total rewards=-27 and episode length=27
# episode=61/500 and total rewards=-22 and episode length=22
# episode=62/500 and total rewards=-21 and episode length=21
# episode=63/500 and total rewards=-22 and episode length=22
# episode=64/500 and total rewards=-40 and episode length=40
# episode=65/500 and total rewards=-31 and episode length=31
# episode=66/500 and total rewards=-25 and episode length=25
# episode=67/500 and total rewards=-182 and episode length=83
# episode=68/500 and total rewards=-31 and episode length=31
# episode=69/500 and total rewards=-47 and episode length=47
# episode=70/500 and total rewards=-25 and episode length=25
# episode=71/500 and total rewards=-41 and episode length=41
# episode=72/500 and total rewards=-25 and episode length=25
# episode=73/500 and total rewards=-25 and episode length=25
# episode=74/500 and total rewards=-24 and episode length=24
# episode=75/500 and total rewards=-19 and episode length=19
# episode=76/500 and total rewards=-19 and episode length=19
# episode=77/500 and total rewards=-19 and episode length=19
# episode=78/500 and total rewards=-17 and episode length=17
# episode=79/500 and total rewards=-19 and episode length=19
# episode=80/500 and total rewards=-423 and episode length=324
# episode=81/500 and total rewards=-67 and episode length=67
# episode=82/500 and total rewards=-71 and episode length=71
# episode=83/500 and total rewards=-45 and episode length=45
# episode=84/500 and total rewards=-41 and episode length=41
# episode=85/500 and total rewards=-50 and episode length=50
# episode=86/500 and total rewards=-28 and episode length=28
# episode=87/500 and total rewards=-71 and episode length=71
# episode=88/500 and total rewards=-33 and episode length=33
# episode=89/500 and total rewards=-39 and episode length=39
# episode=90/500 and total rewards=-72 and episode length=72
# episode=91/500 and total rewards=-35 and episode length=35
# episode=92/500 and total rewards=-27 and episode length=27
# episode=93/500 and total rewards=-27 and episode length=27
# episode=94/500 and total rewards=-153 and episode length=54
# episode=95/500 and total rewards=-17 and episode length=17
# episode=96/500 and total rewards=-28 and episode length=28
# episode=97/500 and total rewards=-23 and episode length=23
# episode=98/500 and total rewards=-30 and episode length=30
# episode=99/500 and total rewards=-22 and episode length=22
# episode=100/500 and total rewards=-19 and episode length=19
# episode=101/500 and total rewards=-17 and episode length=17
# episode=102/500 and total rewards=-18 and episode length=18
# episode=103/500 and total rewards=-30 and episode length=30
# episode=104/500 and total rewards=-17 and episode length=17
# episode=105/500 and total rewards=-21 and episode length=21
# episode=106/500 and total rewards=-131 and episode length=32
# episode=107/500 and total rewards=-17 and episode length=17
# episode=108/500 and total rewards=-23 and episode length=23
# episode=109/500 and total rewards=-17 and episode length=17
# episode=110/500 and total rewards=-23 and episode length=23
# episode=111/500 and total rewards=-17 and episode length=17
# episode=112/500 and total rewards=-20 and episode length=20
# episode=113/500 and total rewards=-17 and episode length=17
# episode=114/500 and total rewards=-27 and episode length=27
# episode=115/500 and total rewards=-24 and episode length=24
# episode=116/500 and total rewards=-26 and episode length=26
# episode=117/500 and total rewards=-21 and episode length=21
# episode=118/500 and total rewards=-25 and episode length=25
# episode=119/500 and total rewards=-20 and episode length=20
# episode=120/500 and total rewards=-19 and episode length=19
# episode=121/500 and total rewards=-19 and episode length=19
# episode=122/500 and total rewards=-22 and episode length=22
# episode=123/500 and total rewards=-132 and episode length=33
# episode=124/500 and total rewards=-19 and episode length=19
# episode=125/500 and total rewards=-19 and episode length=19
# episode=126/500 and total rewards=-20 and episode length=20
# episode=127/500 and total rewards=-19 and episode length=19
# episode=128/500 and total rewards=-27 and episode length=27
# episode=129/500 and total rewards=-31 and episode length=31
# episode=130/500 and total rewards=-18 and episode length=18
# episode=131/500 and total rewards=-22 and episode length=22
# episode=132/500 and total rewards=-21 and episode length=21
# episode=133/500 and total rewards=-122 and episode length=23
# episode=134/500 and total rewards=-22 and episode length=22
# episode=135/500 and total rewards=-23 and episode length=23
# episode=136/500 and total rewards=-22 and episode length=22
# episode=137/500 and total rewards=-28 and episode length=28
# episode=138/500 and total rewards=-26 and episode length=26
# episode=139/500 and total rewards=-21 and episode length=21
# episode=140/500 and total rewards=-18 and episode length=18
# episode=141/500 and total rewards=-18 and episode length=18
# episode=142/500 and total rewards=-22 and episode length=22
# episode=143/500 and total rewards=-20 and episode length=20
# episode=144/500 and total rewards=-23 and episode length=23
# episode=145/500 and total rewards=-118 and episode length=19
# episode=146/500 and total rewards=-19 and episode length=19
# episode=147/500 and total rewards=-25 and episode length=25
# episode=148/500 and total rewards=-20 and episode length=20
# episode=149/500 and total rewards=-17 and episode length=17
# episode=150/500 and total rewards=-25 and episode length=25
# episode=151/500 and total rewards=-18 and episode length=18
# episode=152/500 and total rewards=-123 and episode length=24
# episode=153/500 and total rewards=-17 and episode length=17
# episode=154/500 and total rewards=-19 and episode length=19
# episode=155/500 and total rewards=-20 and episode length=20
# episode=156/500 and total rewards=-19 and episode length=19
# episode=157/500 and total rewards=-51 and episode length=51
# episode=158/500 and total rewards=-18 and episode length=18
# episode=159/500 and total rewards=-25 and episode length=25
# episode=160/500 and total rewards=-22 and episode length=22
# episode=161/500 and total rewards=-22 and episode length=22
# episode=162/500 and total rewards=-19 and episode length=19
# episode=163/500 and total rewards=-18 and episode length=18
# episode=164/500 and total rewards=-23 and episode length=23
# episode=165/500 and total rewards=-21 and episode length=21
# episode=166/500 and total rewards=-17 and episode length=17
# episode=167/500 and total rewards=-19 and episode length=19
# episode=168/500 and total rewards=-22 and episode length=22
# episode=169/500 and total rewards=-17 and episode length=17
# episode=170/500 and total rewards=-17 and episode length=17
# episode=171/500 and total rewards=-19 and episode length=19
# episode=172/500 and total rewards=-17 and episode length=17
# episode=173/500 and total rewards=-19 and episode length=19
# episode=174/500 and total rewards=-21 and episode length=21
# episode=175/500 and total rewards=-19 and episode length=19
# episode=176/500 and total rewards=-21 and episode length=21
# episode=177/500 and total rewards=-17 and episode length=17
# episode=178/500 and total rewards=-17 and episode length=17
# episode=179/500 and total rewards=-17 and episode length=17
# episode=180/500 and total rewards=-17 and episode length=17
# episode=181/500 and total rewards=-17 and episode length=17
# episode=182/500 and total rewards=-17 and episode length=17
# episode=183/500 and total rewards=-17 and episode length=17
# episode=184/500 and total rewards=-26 and episode length=26
# episode=185/500 and total rewards=-18 and episode length=18
# episode=186/500 and total rewards=-17 and episode length=17
# episode=187/500 and total rewards=-17 and episode length=17
# episode=188/500 and total rewards=-19 and episode length=19
# episode=189/500 and total rewards=-22 and episode length=22
# episode=190/500 and total rewards=-17 and episode length=17
# episode=191/500 and total rewards=-19 and episode length=19
# episode=192/500 and total rewards=-19 and episode length=19
# episode=193/500 and total rewards=-19 and episode length=19
# episode=194/500 and total rewards=-19 and episode length=19
# episode=195/500 and total rewards=-24 and episode length=24
# episode=196/500 and total rewards=-24 and episode length=24
# episode=197/500 and total rewards=-19 and episode length=19
# episode=198/500 and total rewards=-23 and episode length=23
# episode=199/500 and total rewards=-17 and episode length=17
# episode=200/500 and total rewards=-17 and episode length=17
# episode=201/500 and total rewards=-17 and episode length=17
# episode=202/500 and total rewards=-23 and episode length=23
# episode=203/500 and total rewards=-22 and episode length=22
# episode=204/500 and total rewards=-27 and episode length=27
# episode=205/500 and total rewards=-21 and episode length=21
# episode=206/500 and total rewards=-21 and episode length=21
# episode=207/500 and total rewards=-17 and episode length=17
# episode=208/500 and total rewards=-18 and episode length=18
# episode=209/500 and total rewards=-18 and episode length=18
# episode=210/500 and total rewards=-28 and episode length=28
# episode=211/500 and total rewards=-28 and episode length=28
# episode=212/500 and total rewards=-28 and episode length=28
# episode=213/500 and total rewards=-22 and episode length=22
# episode=214/500 and total rewards=-19 and episode length=19
# episode=215/500 and total rewards=-17 and episode length=17
# episode=216/500 and total rewards=-21 and episode length=21
# episode=217/500 and total rewards=-25 and episode length=25
# episode=218/500 and total rewards=-19 and episode length=19
# episode=219/500 and total rewards=-21 and episode length=21
# episode=220/500 and total rewards=-20 and episode length=20
# episode=221/500 and total rewards=-17 and episode length=17
# episode=222/500 and total rewards=-21 and episode length=21
# episode=223/500 and total rewards=-24 and episode length=24
# episode=224/500 and total rewards=-19 and episode length=19
# episode=225/500 and total rewards=-17 and episode length=17
# episode=226/500 and total rewards=-24 and episode length=24
# episode=227/500 and total rewards=-17 and episode length=17
# episode=228/500 and total rewards=-23 and episode length=23
# episode=229/500 and total rewards=-18 and episode length=18
# episode=230/500 and total rewards=-25 and episode length=25
# episode=231/500 and total rewards=-20 and episode length=20
# episode=232/500 and total rewards=-18 and episode length=18
# episode=233/500 and total rewards=-20 and episode length=20
# episode=234/500 and total rewards=-17 and episode length=17
# episode=235/500 and total rewards=-18 and episode length=18
# episode=236/500 and total rewards=-26 and episode length=26
# episode=237/500 and total rewards=-18 and episode length=18
# episode=238/500 and total rewards=-17 and episode length=17
# episode=239/500 and total rewards=-24 and episode length=24
# episode=240/500 and total rewards=-19 and episode length=19
# episode=241/500 and total rewards=-23 and episode length=23
# episode=242/500 and total rewards=-17 and episode length=17
# episode=243/500 and total rewards=-18 and episode length=18
# episode=244/500 and total rewards=-20 and episode length=20
# episode=245/500 and total rewards=-19 and episode length=19
# episode=246/500 and total rewards=-20 and episode length=20
# episode=247/500 and total rewards=-20 and episode length=20
# episode=248/500 and total rewards=-21 and episode length=21
# episode=249/500 and total rewards=-20 and episode length=20
# episode=250/500 and total rewards=-21 and episode length=21
# episode=251/500 and total rewards=-19 and episode length=19
# episode=252/500 and total rewards=-17 and episode length=17
# episode=253/500 and total rewards=-20 and episode length=20
# episode=254/500 and total rewards=-19 and episode length=19
# episode=255/500 and total rewards=-19 and episode length=19
# episode=256/500 and total rewards=-17 and episode length=17
# episode=257/500 and total rewards=-21 and episode length=21
# episode=258/500 and total rewards=-17 and episode length=17
# episode=259/500 and total rewards=-18 and episode length=18
# episode=260/500 and total rewards=-21 and episode length=21
# episode=261/500 and total rewards=-19 and episode length=19
# episode=262/500 and total rewards=-18 and episode length=18
# episode=263/500 and total rewards=-17 and episode length=17
# episode=264/500 and total rewards=-22 and episode length=22
# episode=265/500 and total rewards=-22 and episode length=22
# episode=266/500 and total rewards=-17 and episode length=17
# episode=267/500 and total rewards=-17 and episode length=17
# episode=268/500 and total rewards=-17 and episode length=17
# episode=269/500 and total rewards=-18 and episode length=18
# episode=270/500 and total rewards=-17 and episode length=17
# episode=271/500 and total rewards=-17 and episode length=17
# episode=272/500 and total rewards=-20 and episode length=20
# episode=273/500 and total rewards=-17 and episode length=17
# episode=274/500 and total rewards=-18 and episode length=18
# episode=275/500 and total rewards=-20 and episode length=20
# episode=276/500 and total rewards=-17 and episode length=17
# episode=277/500 and total rewards=-19 and episode length=19
# episode=278/500 and total rewards=-19 and episode length=19
# episode=279/500 and total rewards=-17 and episode length=17
# episode=280/500 and total rewards=-18 and episode length=18
# episode=281/500 and total rewards=-17 and episode length=17
# episode=282/500 and total rewards=-18 and episode length=18
# episode=283/500 and total rewards=-21 and episode length=21
# episode=284/500 and total rewards=-18 and episode length=18
# episode=285/500 and total rewards=-17 and episode length=17
# episode=286/500 and total rewards=-18 and episode length=18
# episode=287/500 and total rewards=-17 and episode length=17
# episode=288/500 and total rewards=-24 and episode length=24
# episode=289/500 and total rewards=-17 and episode length=17
# episode=290/500 and total rewards=-19 and episode length=19
# episode=291/500 and total rewards=-121 and episode length=22
# episode=292/500 and total rewards=-18 and episode length=18
# episode=293/500 and total rewards=-20 and episode length=20
# episode=294/500 and total rewards=-20 and episode length=20
# episode=295/500 and total rewards=-19 and episode length=19
# episode=296/500 and total rewards=-17 and episode length=17
# episode=297/500 and total rewards=-17 and episode length=17
# episode=298/500 and total rewards=-24 and episode length=24
# episode=299/500 and total rewards=-118 and episode length=19
# episode=300/500 and total rewards=-17 and episode length=17
# episode=301/500 and total rewards=-17 and episode length=17
# episode=302/500 and total rewards=-17 and episode length=17
# episode=303/500 and total rewards=-19 and episode length=19
# episode=304/500 and total rewards=-20 and episode length=20
# episode=305/500 and total rewards=-17 and episode length=17
# episode=306/500 and total rewards=-20 and episode length=20
# episode=307/500 and total rewards=-17 and episode length=17
# episode=308/500 and total rewards=-18 and episode length=18
# episode=309/500 and total rewards=-27 and episode length=27
# episode=310/500 and total rewards=-17 and episode length=17
# episode=311/500 and total rewards=-17 and episode length=17
# episode=312/500 and total rewards=-18 and episode length=18
# episode=313/500 and total rewards=-21 and episode length=21
# episode=314/500 and total rewards=-20 and episode length=20
# episode=315/500 and total rewards=-20 and episode length=20
# episode=316/500 and total rewards=-121 and episode length=22
# episode=317/500 and total rewards=-22 and episode length=22
# episode=318/500 and total rewards=-25 and episode length=25
# episode=319/500 and total rewards=-19 and episode length=19
# episode=320/500 and total rewards=-17 and episode length=17
# episode=321/500 and total rewards=-20 and episode length=20
# episode=322/500 and total rewards=-23 and episode length=23
# episode=323/500 and total rewards=-19 and episode length=19
# episode=324/500 and total rewards=-19 and episode length=19
# episode=325/500 and total rewards=-20 and episode length=20
# episode=326/500 and total rewards=-17 and episode length=17
# episode=327/500 and total rewards=-21 and episode length=21
# episode=328/500 and total rewards=-22 and episode length=22
# episode=329/500 and total rewards=-17 and episode length=17
# episode=330/500 and total rewards=-19 and episode length=19
# episode=331/500 and total rewards=-17 and episode length=17
# episode=332/500 and total rewards=-30 and episode length=30
# episode=333/500 and total rewards=-19 and episode length=19
# episode=334/500 and total rewards=-17 and episode length=17
# episode=335/500 and total rewards=-17 and episode length=17
# episode=336/500 and total rewards=-22 and episode length=22
# episode=337/500 and total rewards=-21 and episode length=21
# episode=338/500 and total rewards=-22 and episode length=22
# episode=339/500 and total rewards=-19 and episode length=19
# episode=340/500 and total rewards=-23 and episode length=23
# episode=341/500 and total rewards=-19 and episode length=19
# episode=342/500 and total rewards=-23 and episode length=23
# episode=343/500 and total rewards=-22 and episode length=22
# episode=344/500 and total rewards=-17 and episode length=17
# episode=345/500 and total rewards=-120 and episode length=21
# episode=346/500 and total rewards=-21 and episode length=21
# episode=347/500 and total rewards=-18 and episode length=18
# episode=348/500 and total rewards=-17 and episode length=17
# episode=349/500 and total rewards=-17 and episode length=17
# episode=350/500 and total rewards=-17 and episode length=17
# episode=351/500 and total rewards=-19 and episode length=19
# episode=352/500 and total rewards=-19 and episode length=19
# episode=353/500 and total rewards=-17 and episode length=17
# episode=354/500 and total rewards=-23 and episode length=23
# episode=355/500 and total rewards=-17 and episode length=17
# episode=356/500 and total rewards=-17 and episode length=17
# episode=357/500 and total rewards=-17 and episode length=17
# episode=358/500 and total rewards=-18 and episode length=18
# episode=359/500 and total rewards=-19 and episode length=19
# episode=360/500 and total rewards=-21 and episode length=21
# episode=361/500 and total rewards=-30 and episode length=30
# episode=362/500 and total rewards=-17 and episode length=17
# episode=363/500 and total rewards=-19 and episode length=19
# episode=364/500 and total rewards=-119 and episode length=20
# episode=365/500 and total rewards=-120 and episode length=21
# episode=366/500 and total rewards=-17 and episode length=17
# episode=367/500 and total rewards=-21 and episode length=21
# episode=368/500 and total rewards=-18 and episode length=18
# episode=369/500 and total rewards=-21 and episode length=21
# episode=370/500 and total rewards=-19 and episode length=19
# episode=371/500 and total rewards=-17 and episode length=17
# episode=372/500 and total rewards=-17 and episode length=17
# episode=373/500 and total rewards=-19 and episode length=19
# episode=374/500 and total rewards=-19 and episode length=19
# episode=375/500 and total rewards=-22 and episode length=22
# episode=376/500 and total rewards=-19 and episode length=19
# episode=377/500 and total rewards=-17 and episode length=17
# episode=378/500 and total rewards=-18 and episode length=18
# episode=379/500 and total rewards=-22 and episode length=22
# episode=380/500 and total rewards=-17 and episode length=17
# episode=381/500 and total rewards=-18 and episode length=18
# episode=382/500 and total rewards=-18 and episode length=18
# episode=383/500 and total rewards=-19 and episode length=19
# episode=384/500 and total rewards=-20 and episode length=20
# episode=385/500 and total rewards=-19 and episode length=19
# episode=386/500 and total rewards=-17 and episode length=17
# episode=387/500 and total rewards=-17 and episode length=17
# episode=388/500 and total rewards=-19 and episode length=19
# episode=389/500 and total rewards=-18 and episode length=18
# episode=390/500 and total rewards=-24 and episode length=24
# episode=391/500 and total rewards=-17 and episode length=17
# episode=392/500 and total rewards=-19 and episode length=19
# episode=393/500 and total rewards=-17 and episode length=17
# episode=394/500 and total rewards=-22 and episode length=22
# episode=395/500 and total rewards=-21 and episode length=21
# episode=396/500 and total rewards=-25 and episode length=25
# episode=397/500 and total rewards=-24 and episode length=24
# episode=398/500 and total rewards=-18 and episode length=18
# episode=399/500 and total rewards=-17 and episode length=17
# episode=400/500 and total rewards=-17 and episode length=17
# episode=401/500 and total rewards=-17 and episode length=17
# episode=402/500 and total rewards=-19 and episode length=19
# episode=403/500 and total rewards=-21 and episode length=21
# episode=404/500 and total rewards=-19 and episode length=19
# episode=405/500 and total rewards=-17 and episode length=17
# episode=406/500 and total rewards=-19 and episode length=19
# episode=407/500 and total rewards=-17 and episode length=17
# episode=408/500 and total rewards=-17 and episode length=17
# episode=409/500 and total rewards=-17 and episode length=17
# episode=410/500 and total rewards=-122 and episode length=23
# episode=411/500 and total rewards=-19 and episode length=19
# episode=412/500 and total rewards=-18 and episode length=18
# episode=413/500 and total rewards=-23 and episode length=23
# episode=414/500 and total rewards=-19 and episode length=19
# episode=415/500 and total rewards=-19 and episode length=19
# episode=416/500 and total rewards=-17 and episode length=17
# episode=417/500 and total rewards=-19 and episode length=19
# episode=418/500 and total rewards=-17 and episode length=17
# episode=419/500 and total rewards=-17 and episode length=17
# episode=420/500 and total rewards=-17 and episode length=17
# episode=421/500 and total rewards=-17 and episode length=17
# episode=422/500 and total rewards=-17 and episode length=17
# episode=423/500 and total rewards=-18 and episode length=18
# episode=424/500 and total rewards=-19 and episode length=19
# episode=425/500 and total rewards=-20 and episode length=20
# episode=426/500 and total rewards=-19 and episode length=19
# episode=427/500 and total rewards=-17 and episode length=17
# episode=428/500 and total rewards=-17 and episode length=17
# episode=429/500 and total rewards=-18 and episode length=18
# episode=430/500 and total rewards=-18 and episode length=18
# episode=431/500 and total rewards=-20 and episode length=20
# episode=432/500 and total rewards=-17 and episode length=17
# episode=433/500 and total rewards=-17 and episode length=17
# episode=434/500 and total rewards=-21 and episode length=21
# episode=435/500 and total rewards=-20 and episode length=20
# episode=436/500 and total rewards=-19 and episode length=19
# episode=437/500 and total rewards=-23 and episode length=23
# episode=438/500 and total rewards=-17 and episode length=17
# episode=439/500 and total rewards=-17 and episode length=17
# episode=440/500 and total rewards=-17 and episode length=17
# episode=441/500 and total rewards=-22 and episode length=22
# episode=442/500 and total rewards=-20 and episode length=20
# episode=443/500 and total rewards=-19 and episode length=19
# episode=444/500 and total rewards=-17 and episode length=17
# episode=445/500 and total rewards=-22 and episode length=22
# episode=446/500 and total rewards=-17 and episode length=17
# episode=447/500 and total rewards=-20 and episode length=20
# episode=448/500 and total rewards=-19 and episode length=19
# episode=449/500 and total rewards=-17 and episode length=17
# episode=450/500 and total rewards=-23 and episode length=23
# episode=451/500 and total rewards=-17 and episode length=17
# episode=452/500 and total rewards=-18 and episode length=18
# episode=453/500 and total rewards=-19 and episode length=19
# episode=454/500 and total rewards=-19 and episode length=19
# episode=455/500 and total rewards=-17 and episode length=17
# episode=456/500 and total rewards=-19 and episode length=19
# episode=457/500 and total rewards=-31 and episode length=31
# episode=458/500 and total rewards=-19 and episode length=19
# episode=459/500 and total rewards=-23 and episode length=23
# episode=460/500 and total rewards=-20 and episode length=20
# episode=461/500 and total rewards=-19 and episode length=19
# episode=462/500 and total rewards=-17 and episode length=17
# episode=463/500 and total rewards=-17 and episode length=17
# episode=464/500 and total rewards=-19 and episode length=19
# episode=465/500 and total rewards=-17 and episode length=17
# episode=466/500 and total rewards=-17 and episode length=17
# episode=467/500 and total rewards=-22 and episode length=22
# episode=468/500 and total rewards=-17 and episode length=17
# episode=469/500 and total rewards=-17 and episode length=17
# episode=470/500 and total rewards=-18 and episode length=18
# episode=471/500 and total rewards=-23 and episode length=23
# episode=472/500 and total rewards=-18 and episode length=18
# episode=473/500 and total rewards=-17 and episode length=17
# episode=474/500 and total rewards=-18 and episode length=18
# episode=475/500 and total rewards=-17 and episode length=17
# episode=476/500 and total rewards=-22 and episode length=22
# episode=477/500 and total rewards=-17 and episode length=17
# episode=478/500 and total rewards=-17 and episode length=17
# episode=479/500 and total rewards=-19 and episode length=19
# episode=480/500 and total rewards=-19 and episode length=19
# episode=481/500 and total rewards=-19 and episode length=19
# episode=482/500 and total rewards=-20 and episode length=20
# episode=483/500 and total rewards=-21 and episode length=21
# episode=484/500 and total rewards=-22 and episode length=22
# episode=485/500 and total rewards=-17 and episode length=17
# episode=486/500 and total rewards=-23 and episode length=23
# episode=487/500 and total rewards=-19 and episode length=19
# episode=488/500 and total rewards=-17 and episode length=17
# episode=489/500 and total rewards=-117 and episode length=18
# episode=490/500 and total rewards=-19 and episode length=19
# episode=491/500 and total rewards=-22 and episode length=22
# episode=492/500 and total rewards=-21 and episode length=21
# episode=493/500 and total rewards=-18 and episode length=18
# episode=494/500 and total rewards=-19 and episode length=19
# episode=495/500 and total rewards=-17 and episode length=17
# episode=496/500 and total rewards=-18 and episode length=18
# episode=497/500 and total rewards=-18 and episode length=18
# episode=498/500 and total rewards=-17 and episode length=17
# episode=499/500 and total rewards=-17 and episode length=17
# episode=500/500 and total rewards=-18 and episode length=18

# %%
# What agent learn 
env=gym.make("CliffWalking-v1",render_mode="human")

state,_=env.reset()
done=False
total_reward=0
epsiode_len=0

while not done:
    action=np.argmax(Q[state])
    state,reward,terminated,truncated,_=env.step(action)
    done=terminated or truncated
    total_reward+=reward
    
    epsiode_len+=1
    
print(f"total rewards={total_reward} and episode length={epsiode_len}")
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 while not done:
#       9     action=np.argmax(Q[state])
# ---> 10     next_state,reward,terminated,truncated,_=env.step(action)
#      11     done=terminated or truncated
#      12     total_reward+=reward
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:202, in CliffWalkingEnv.step(self, a)
#     199 self.lastaction = a
#     201 if self.render_mode == "human":
# --> 202     self.render()
#     203 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     204 return int(s), r, t, False, {"prob": p}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:228, in CliffWalkingEnv.render(self)
#     226     return self._render_text()
#     227 else:
# --> 228     return self._render_gui(self.render_mode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\gymnasium\envs\toy_text\cliffwalking.py:315, in CliffWalkingEnv._render_gui(self, mode)
#     313     pygame.event.pump()
#     314     pygame.display.update()
# --> 315     self.clock.tick(self.metadata["render_fps"])
#     316 else:  # rgb_array
#     317     return np.transpose(
#     318         np.array(pygame.surfarray.pixels3d(self.window_surface)), axes=(1, 0, 2)
#     319     )
#
# KeyboardInterrupt:
