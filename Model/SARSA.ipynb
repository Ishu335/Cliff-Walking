# %%
# !pip install gymnasium
# Out:
# ...
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 952.1/952.1 kB 5.7 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
# ...

# %%
# !pip install "gynasium[tok-text]"
# Out:
# ERROR: Could not find a version that satisfies the requirement gynasium[tok-text] (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for gynasium[tok-text]

# %%
import numpy as np
import pandas as pd
import random
